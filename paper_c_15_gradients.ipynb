# %%
# import spacy
import shap
import torch
from transformers import BertTokenizer, BertForSequenceClassification

from lib.utils import load_jsonl_file
from lib.ner_processing import custom_anonymize_text

SEED = 42
BATCH_SIZE = 16
CLASS_NAMES = ['continue', 'not_continue']

# Load dataset
DATASET = load_jsonl_file("shared_data/dataset_2_6_2b.jsonl")
# Select a sample from the dataset
text  = DATASET[1]["text"]
text_id = DATASET[1]["id"]

# nlp = spacy.load("en_core_web_trf")


def get_device():
  """Returns the appropriate device available in the system: CUDA, MPS, or CPU"""
  if torch.backends.mps.is_available():
    return torch.device("mps")
  elif torch.cuda.is_available():
    return torch.device("cuda")
  else:
    return torch.device("cpu")


# Set device
device = get_device()
print(f"\nUsing device: {str(device).upper()}\n")

# Initialize constants
BERT_MODEL = 'bert-base-uncased'
MODEL_PATH = 'models/2/paper_b_hop_bert_reclass.pth'

# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased',
                                                      num_labels=len(CLASS_NAMES),
                                                      hidden_dropout_prob=0.1)

# Move the model to the device
model = model.to(device)
# Load the model weights
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
# Set the model to evaluation mode
model.eval()


def predict(text):
  tv = torch.tensor([tokenizer.encode(v, padding=True, max_length=512, truncation=True) for v in text], device=device)
  attention_mask = (tv != 0).type(torch.int64).to(device)
  probabilities = model(tv, attention_mask=attention_mask)[0]
  return probabilities.detach().cpu().numpy()


# Initialize the SHAP explainer
explainer = shap.Explainer(
  predict, 
  tokenizer, 
  output_names=CLASS_NAMES, 
  seed=SEED
)

"""sentence1, sentence2 = text.split('[SEP]')
text = sentence1.strip() + " " + sentence2.strip()"""


# Compute SHAP values for the selected samples
shap_values = explainer([text])

# Visualize the SHAP values
shap.plots.text(shap_values)

# shap.save_html(f"xnlp/model_3_shap_{text_id}.html", shap.plots.text(shap_values[0]))
# Out:
# Loading data from shared_data/dataset_2_6_2b.jsonl...
# Loaded 3566 items.
#
# Using device: MPS
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_mdgyhjzuheeyldqcgfta = '_tp_mdgyhjzuheeyldqcgfta_output_0';
#     document._zoom_mdgyhjzuheeyldqcgfta = undefined;
#     function _output_onclick_mdgyhjzuheeyldqcgfta(i) {
#         var next_id = undefined;
#
#         if (document._zoom_mdgyhjzuheeyldqcgfta !== undefined) {
#             document.getElementById(document._zoom_mdgyhjzuheeyldqcgfta+ '_zoom').style.display = 'none';
#
#             if (document._zoom_mdgyhjzuheeyldqcgfta === '_tp_mdgyhjzuheeyldqcgfta_output_' + i) {
#                 document.getElementById(document._zoom_mdgyhjzuheeyldqcgfta).style.display = 'block';
#                 document.getElementById(document._zoom_mdgyhjzuheeyldqcgfta+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_mdgyhjzuheeyldqcgfta).style.display = 'none';
#                 document.getElementById(document._zoom_mdgyhjzuheeyldqcgfta+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_mdgyhjzuheeyldqcgfta !== '_tp_mdgyhjzuheeyldqcgfta_output_' + i) {
#             next_id = '_tp_mdgyhjzuheeyldqcgfta_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_mdgyhjzuheeyldqcgfta = next_id;
#     }
#     function _output_onmouseover_mdgyhjzuheeyldqcgfta(i, el) {
#         if (document._zoom_mdgyhjzuheeyldqcgfta !== undefined) { return; }
#         if (document._hover_mdgyhjzuheeyldqcgfta !== undefined) {
#             document.getElementById(document._hover_mdgyhjzuheeyldqcgfta + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_mdgyhjzuheeyldqcgfta).style.display = 'none';
#         }
#         document.getElementById('_tp_mdgyhjzuheeyldqcgfta_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_mdgyhjzuheeyldqcgfta = '_tp_mdgyhjzuheeyldqcgfta_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.865993265993266); border-radius: 3px; padding: 0px" id="_tp_mdgyhjzuheeyldqcgfta_output_0_name"
#     onclick="_output_onclick_mdgyhjzuheeyldqcgfta(0)"
#     onmouseover="_output_onmouseover_mdgyhjzuheeyldqcgfta(0, this);">continue</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_mdgyhjzuheeyldqcgfta_output_1_name"
#     onclick="_output_onclick_mdgyhjzuheeyldqcgfta(1)"
#     onmouseover="_output_onmouseover_mdgyhjzuheeyldqcgfta(1, this);">not_continue</div><br><br><div id='_tp_mdgyhjzuheeyldqcgfta_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="53.76915103810431%" y1="33" x2="53.76915103810431%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="53.76915103810431%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0</text><line x1="44.08906010437709%" y1="33" x2="44.08906010437709%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="44.08906010437709%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="34.40896917064987%" y1="33" x2="34.40896917064987%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.40896917064987%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2</text><line x1="24.728878236922643%" y1="33" x2="24.728878236922643%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="24.728878236922643%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="15.04878730319542%" y1="33" x2="15.04878730319542%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="15.04878730319542%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="63.44924197183154%" y1="33" x2="63.44924197183154%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.44924197183154%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="73.12933290555875%" y1="33" x2="73.12933290555875%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.12933290555875%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="82.80942383928597%" y1="33" x2="82.80942383928597%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="82.80942383928597%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><line x1="92.4895147730132%" y1="33" x2="92.4895147730132%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="92.4895147730132%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">4</text><line x1="46.772905625770605%" y1="33" x2="46.772905625770605%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="46.772905625770605%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-0.722746</text><text x="46.772905625770605%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.722746</text><text x="46.772905625770605%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="93.08695511583295%" y1="33" x2="93.08695511583295%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="93.08695511583295%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">4.06172</text><text x="93.08695511583295%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">4.06172</text><text x="93.08695511583295%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">continue</tspan>(inputs)</text><rect x="44.87153909380404%" width="48.21541602202892%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="84.51372821301 ...
