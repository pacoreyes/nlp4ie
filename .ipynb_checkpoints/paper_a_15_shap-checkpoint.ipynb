# %%
import shap
import torch
from transformers import BertTokenizer, BertForSequenceClassification

from lib.utils import load_jsonl_file

# BATCH_SIZE = 16
CLASS_NAMES = ['monologic', 'dialogic']

# Load dataset
DATASET = load_jsonl_file("shared_data/dataset_1_6_1b_test.jsonl")
# Load mismatched datapoint
mismatched_datapoints = load_jsonl_file("shared_data/dataset_1_8_2b_misclassified_examples.jsonl")
mismatched_datapoints = mismatched_datapoints[:1]


def get_device():
  """Returns the appropriate device available in the system: CUDA, MPS, or CPU"""
  if torch.backends.mps.is_available():
    return torch.device("mps")
  elif torch.cuda.is_available():
    return torch.device("cuda")
  else:
    return torch.device("cpu")


# Set device
device = get_device()
print(f"\nUsing device: {str(device).upper()}\n")

# Initialize constants
BERT_MODEL = 'bert-base-uncased'
# MODEL_PATH = 'models/1/paper_a_x_dl_bert_train_hop_bert.pth'
MODEL_PATH = 'models/1/paper_a_bert_solo.pth'

# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased',
                                                      num_labels=len(CLASS_NAMES),
                                                      hidden_dropout_prob=0.1)

# Move the model to the device
model = model.to(device)
# Load the model weights
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
# Set the model to evaluation mode
model.eval()


"""# Define a prediction function that the SHAP explainer will use
def predict(texts):
  # Tokenize the input texts
  inputs = tokenizer(texts, padding=True, truncation=True, max_length=512, return_tensors="pt")
  # Move inputs to the same device as model
  inputs = {k: v.to(model.device) for k, v in inputs.items()}
  # Get model outputs (logits)
  with torch.no_grad():
    outputs = model(**inputs)
  # Apply softmax to logits to get probabilities
  probabilities = torch.nn.functional.softmax(outputs.logits, dim=-1)
  return probabilities.cpu().detach().numpy()"""


def predict(text):
  tv = torch.tensor([tokenizer.encode(v, padding='max_length', max_length=512, truncation=True) for v in text], device=device)
  attention_mask = (tv != 0).type(torch.int64).to(device)
  probabilities = model(tv, attention_mask=attention_mask)[0]
  return probabilities.detach().cpu().numpy()


# Initialize the SHAP explainer
explainer = shap.Explainer(predict, tokenizer, output_names=["monologic", "dialogic"])

"""selected_texts = []
for mismatch in mismatched_datapoints:
  datapoint = None
  for data in DATASET:
    if data["id"] == mismatch["id"]:
      selected_texts.append(data["text"])
      break"""

# Compute SHAP values for the selected samples
shap_values = explainer([DATASET[0]["text"]])

# Visualize the SHAP values
shap.plots.text(shap_values)
# Out:
# Loading data from shared_data/dataset_1_6_1b_test.jsonl...
# Loaded 468 items.
# Loading data from shared_data/dataset_1_8_2b_misclassified_examples.jsonl...
# Loaded 9 items.
#
# Using device: MPS
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/498 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:20, 20.94s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_mjmrqwcrzbfkovtnhyzu = '_tp_mjmrqwcrzbfkovtnhyzu_output_0';
#     document._zoom_mjmrqwcrzbfkovtnhyzu = undefined;
#     function _output_onclick_mjmrqwcrzbfkovtnhyzu(i) {
#         var next_id = undefined;
#
#         if (document._zoom_mjmrqwcrzbfkovtnhyzu !== undefined) {
#             document.getElementById(document._zoom_mjmrqwcrzbfkovtnhyzu+ '_zoom').style.display = 'none';
#
#             if (document._zoom_mjmrqwcrzbfkovtnhyzu === '_tp_mjmrqwcrzbfkovtnhyzu_output_' + i) {
#                 document.getElementById(document._zoom_mjmrqwcrzbfkovtnhyzu).style.display = 'block';
#                 document.getElementById(document._zoom_mjmrqwcrzbfkovtnhyzu+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_mjmrqwcrzbfkovtnhyzu).style.display = 'none';
#                 document.getElementById(document._zoom_mjmrqwcrzbfkovtnhyzu+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_mjmrqwcrzbfkovtnhyzu !== '_tp_mjmrqwcrzbfkovtnhyzu_output_' + i) {
#             next_id = '_tp_mjmrqwcrzbfkovtnhyzu_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_mjmrqwcrzbfkovtnhyzu = next_id;
#     }
#     function _output_onmouseover_mjmrqwcrzbfkovtnhyzu(i, el) {
#         if (document._zoom_mjmrqwcrzbfkovtnhyzu !== undefined) { return; }
#         if (document._hover_mjmrqwcrzbfkovtnhyzu !== undefined) {
#             document.getElementById(document._hover_mjmrqwcrzbfkovtnhyzu + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_mjmrqwcrzbfkovtnhyzu).style.display = 'none';
#         }
#         document.getElementById('_tp_mjmrqwcrzbfkovtnhyzu_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_mjmrqwcrzbfkovtnhyzu = '_tp_mjmrqwcrzbfkovtnhyzu_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_mjmrqwcrzbfkovtnhyzu_output_0_name"
#     onclick="_output_onclick_mjmrqwcrzbfkovtnhyzu(0)"
#     onmouseover="_output_onmouseover_mjmrqwcrzbfkovtnhyzu(0, this);">monologic</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.5743315508021389); border-radius: 3px; padding: 0px" id="_tp_mjmrqwcrzbfkovtnhyzu_output_1_name"
#     onclick="_output_onclick_mjmrqwcrzbfkovtnhyzu(1)"
#     onmouseover="_output_onmouseover_mjmrqwcrzbfkovtnhyzu(1, this);">dialogic</div><br><br><div id='_tp_mjmrqwcrzbfkovtnhyzu_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="54.91879315028175%" y1="33" x2="54.91879315028175%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="54.91879315028175%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="36.5642260345545%" y1="33" x2="36.5642260345545%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.5642260345545%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="18.209658918827245%" y1="33" x2="18.209658918827245%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="18.209658918827245%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="73.273360266009%" y1="33" x2="73.273360266009%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="73.273360266009%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="91.62792738173627%" y1="33" x2="91.62792738173627%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.62792738173627%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><line x1="27.104358862614184%" y1="33" x2="27.104358862614184%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="27.104358862614184%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-0.515396</text><text x="27.104358862614184%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.515396</text><text x="27.104358862614184%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="93.1974267000716%" y1="33" x2="93.1974267000716%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="93.1974267000716%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">3.08551</text><text x="93.1974267000716%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">3.08551</text><text x="93.1974267000716%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">monologic</tspan>(inputs)</text><rect x="26.943303585416686%" width="66.25412311465492%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="90.40361347045172%" x2="93.1974267000716%" y1="60" y2="60" id="_fb_thxmhlbwkslwfydxgpqk_ind_32" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="91.80052008526167%" y="71" font-size="12px" id="_fs_thxmhlbwkslwfydxgpqk_ind_32" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.152</text><svg x="90.40361347045172%" y="40" height="20" width="2.793813229619886%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">this achievement has been made possible by the patriotic voluntary cooperation of businessmen</text>  </svg></svg><line x1="87.91610977722237%" x2="90.40361347045172%" y1="60" y2="60" id="_fb_thxmhlbwkslwfydxgpqk_ind_33" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="89.15986162383705%" y="71" font-size="12px" id="_fs_thxmhlbwkslwfydxgpqk_ind_33" fill="rgb(255.0, 0.0, 81.0808360 ...
