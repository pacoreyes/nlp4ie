# %%
import shap
import torch
from transformers import BertTokenizer, BertForSequenceClassification

from lib.utils import load_jsonl_file

BATCH_SIZE = 16

CLASS_NAMES = ['monologic', 'dialogic']

# Load dataset
DATASET = load_jsonl_file("shared_data/dataset_1_6_1b_test.jsonl")
# Load mismatched datapoint
mismatched_datapoints = load_jsonl_file("shared_data/dataset_1_8_2b_misclassified_examples.jsonl")
mismatched_datapoints = mismatched_datapoints[:5]


def get_device():
  """Returns the appropriate device available in the system: CUDA, MPS, or CPU"""
  if torch.backends.mps.is_available():
    return torch.device("mps")
  elif torch.cuda.is_available():
    return torch.device("cuda")
  else:
    return torch.device("cpu")


# Set device
device = get_device()
print(f"\nUsing device: {str(device).upper()}\n")

# Initialize constants
BERT_MODEL = 'bert-base-uncased'
MODEL_PATH = 'models/1/paper_a_x_dl_bert_train_hop_bert.pth'

# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased',
                                                      num_labels=len(CLASS_NAMES),
                                                      hidden_dropout_prob=0.1)

# Move the model to the device
model = model.to(device)
# Load the model weights
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
# Set the model to evaluation mode
model.eval()


"""# Define a prediction function that the SHAP explainer will use
def predict(texts):
  # Tokenize the input texts
  inputs = tokenizer(texts, padding=True, truncation=True, max_length=512, return_tensors="pt")
  # Move inputs to the same device as model
  inputs = {k: v.to(model.device) for k, v in inputs.items()}
  # Get model outputs (logits)
  with torch.no_grad():
    outputs = model(**inputs)
  # Apply softmax to logits to get probabilities
  probabilities = torch.nn.functional.softmax(outputs.logits, dim=-1)
  return probabilities.cpu().detach().numpy()"""


def f(x):
  tv = torch.tensor([tokenizer.encode(v, padding='max_length', max_length=512, truncation=True) for v in x],
                    device=device)
  attention_mask = (tv != 0).type(torch.int64).to(device)
  _outputs = model(tv, attention_mask=attention_mask)[0]
  return _outputs.detach().cpu().numpy()



# Initialize the SHAP explainer
explainer = shap.Explainer(f, tokenizer, output_names=["monologic", "dialogic"])

selected_texts = []
for mismatch in mismatched_datapoints:
  datapoint = None
  for data in DATASET:
    if data["id"] == mismatch["id"]:
      """print("---")
      print(data["text"])
      print("---")"""
      selected_texts.append(data["text"])
      break

"""print(type(selected_texts))
print(type(selected_texts[0]))
print(selected_texts[0])"""

# Sample single string input
single_text = "This is a test sentence to check the explainer."

# Try computing SHAP values for the single string
shap_values_single = explainer([single_text])  # Note: passing a list with a single string

# If no error, try visualizing the SHAP values
if shap_values_single:
    shap.plots.text(shap_values_single)


"""# Compute SHAP values for the selected samples
shap_values = explainer(selected_texts)

# Visualize the SHAP values
shap.plots.text(shap_values)"""
# Out:
# Loading data from shared_data/dataset_1_6_1b_test.jsonl...
# Loaded 468 items.
# Loading data from shared_data/dataset_1_8_2b_misclassified_examples.jsonl...
# Loaded 23 items.
#
# Using device: MPS
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/156 [00:00<?, ?it/s]
# PartitionExplainer explainer: 2it [00:10, 10.56s/it]
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_wgetjxidxysvqapvsqer = '_tp_wgetjxidxysvqapvsqer_output_0';
#     document._zoom_wgetjxidxysvqapvsqer = undefined;
#     function _output_onclick_wgetjxidxysvqapvsqer(i) {
#         var next_id = undefined;
#
#         if (document._zoom_wgetjxidxysvqapvsqer !== undefined) {
#             document.getElementById(document._zoom_wgetjxidxysvqapvsqer+ '_zoom').style.display = 'none';
#
#             if (document._zoom_wgetjxidxysvqapvsqer === '_tp_wgetjxidxysvqapvsqer_output_' + i) {
#                 document.getElementById(document._zoom_wgetjxidxysvqapvsqer).style.display = 'block';
#                 document.getElementById(document._zoom_wgetjxidxysvqapvsqer+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_wgetjxidxysvqapvsqer).style.display = 'none';
#                 document.getElementById(document._zoom_wgetjxidxysvqapvsqer+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_wgetjxidxysvqapvsqer !== '_tp_wgetjxidxysvqapvsqer_output_' + i) {
#             next_id = '_tp_wgetjxidxysvqapvsqer_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_wgetjxidxysvqapvsqer = next_id;
#     }
#     function _output_onmouseover_wgetjxidxysvqapvsqer(i, el) {
#         if (document._zoom_wgetjxidxysvqapvsqer !== undefined) { return; }
#         if (document._hover_wgetjxidxysvqapvsqer !== undefined) {
#             document.getElementById(document._hover_wgetjxidxysvqapvsqer + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_wgetjxidxysvqapvsqer).style.display = 'none';
#         }
#         document.getElementById('_tp_wgetjxidxysvqapvsqer_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_wgetjxidxysvqapvsqer = '_tp_wgetjxidxysvqapvsqer_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.6531590413943356); border-radius: 3px; padding: 0px" id="_tp_wgetjxidxysvqapvsqer_output_0_name"
#     onclick="_output_onclick_wgetjxidxysvqapvsqer(0)"
#     onmouseover="_output_onmouseover_wgetjxidxysvqapvsqer(0, this);">monologic</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_wgetjxidxysvqapvsqer_output_1_name"
#     onclick="_output_onclick_wgetjxidxysvqapvsqer(1)"
#     onmouseover="_output_onmouseover_wgetjxidxysvqapvsqer(1, this);">dialogic</div><br><br><div id='_tp_wgetjxidxysvqapvsqer_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="45.98895486121739%" y1="33" x2="45.98895486121739%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="45.98895486121739%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="34.062025299896604%" y1="33" x2="34.062025299896604%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.062025299896604%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="22.135095738575824%" y1="33" x2="22.135095738575824%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="22.135095738575824%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2</text><line x1="10.208166177255041%" y1="33" x2="10.208166177255041%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="10.208166177255041%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="57.91588442253818%" y1="33" x2="57.91588442253818%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="57.91588442253818%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="69.84281398385895%" y1="33" x2="69.84281398385895%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="69.84281398385895%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="81.76974354517974%" y1="33" x2="81.76974354517974%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="81.76974354517974%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><line x1="76.00253845968288%" y1="33" x2="76.00253845968288%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="76.00253845968288%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">2.51646</text><text x="76.00253845968288%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2.51646</text><text x="76.00253845968288%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="25.611583527523916%" y1="33" x2="25.611583527523916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="25.611583527523916%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-1.70852</text><text x="25.611583527523916%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-1.70852</text><text x="25.611583527523916%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">monologic</tspan>(inputs)</text><rect x="13.05578354158964%" width="12.555799985934273%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="14.475023055839104%" x2="25.611583527523916%" y1="60" y2="60" id="_fb_pkgofslanzuigpfruvav_ind_9" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="20.04330329168151%" y="71" font-size="12px" id="_fs_pkgofslanzuigpfruvav_ind_9" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.934</text><svg x="14.475023055839104%" y="40" height="20" width="11.136560471684811%">  <svg x="0" y="0" width="100%" height="100%">    <te ...
# '# Compute SHAP values for the selected samples\nshap_values = explainer(selected_texts)\n\n# Visualize the SHAP values\nshap.plots.text(shap_values)'
